# %%
import pandas as pd

# %%
wrecks_and_sites_df = pd.read_csv('Resources/wrecks_and_sites.csv')

# %%
wrecks_and_sites_df
# Out:
#       Record #  Vessel Terms  \
# 0        14620       UNKNOWN
# 1        14292       UNKNOWN
# 2        14296       ALGERIA
# 3        14298       UNKNOWN
# 4        14207       UNKNOWN
# ...        ...           ...
# 6217      2886  NORHTEASTERN
# 6218      2887        ARRAYO
# 6219      2889        NORDAL
# 6220     14917   USS VIRGINA
# 6221     14635       UNKNOWN
#
#                                            Feature Type        Lat        Lng  \
# 0     Wreck - Submerged, dangerous to surface naviga...  42.143528 -80.114556
# 1     Wreck - Submerged, dangerous to surface naviga...  41.498284 -81.759593
# 2     Wreck - Submerged, dangerous to surface naviga...  41.520448 -81.716076
# 3     Wreck - Submerged, dangerous to surface naviga...  41.512713 -81.709879
# 4     Wreck - Submerged, dangerous to surface naviga...  42.993389 -82.426583
# ...                                                 ...        ...        ...
# ...

# %%
copy = wrecks_and_sites_df.copy()

# %%
copy = copy.dropna(subset = ['Dive Site Name'])

# %%
copy.head()
# Out:
#    Record # Vessel Terms                                       Feature Type  \
# 0     14620      UNKNOWN  Wreck - Submerged, dangerous to surface naviga...
# 1     14292      UNKNOWN  Wreck - Submerged, dangerous to surface naviga...
# 2     14296      ALGERIA  Wreck - Submerged, dangerous to surface naviga...
# 3     14298      UNKNOWN  Wreck - Submerged, dangerous to surface naviga...
# 4     14207      UNKNOWN  Wreck - Submerged, dangerous to surface naviga...
#
#          Lat        Lng GP Quality   Dive Site Name  Dive Site ID  \
# 0  42.143528 -80.114556       High     Presque Isle       23369.0
# 1  41.498284 -81.759593       High          Mecosta       23908.0
# 2  41.520448 -81.716076       High          Mecosta       23908.0
# 3  41.512713 -81.709879       High          Mecosta       23908.0
# 4  42.993389 -82.426583       High  St. Clair River       22589.0
#
#    Distance from Wreck
# 0                 1.97
# 1                17.20
# 2                16.96
# ...

# %%
#df.a = df.a.astype(float)
copy["Dive Site ID"] = copy["Dive Site ID"].astype(int)
copy
# Out:
# /Users/chloe/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Record #  Vessel Terms  \
# 0        14620       UNKNOWN
# 1        14292       UNKNOWN
# 2        14296       ALGERIA
# 3        14298       UNKNOWN
# 4        14207       UNKNOWN
# ...        ...           ...
# 6217      2886  NORHTEASTERN
# 6218      2887        ARRAYO
# 6219      2889        NORDAL
# 6220     14917   USS VIRGINA
# 6221     14635       UNKNOWN
#
#                                            Feature Type        Lat        Lng  \
# 0     Wreck - Submerged, dangerous to surface naviga...  42.143528 -80.114556
# ...

# %%
wrecks_and_sites_df = copy

# %%
wrecks_df = wrecks_and_sites_df[["Record #", "Vessel Terms", "Feature Type", "Lat", "Lng", "GP Quality"]]
wrecks_df
# Out:
#       Record #  Vessel Terms  \
# 0        14620       UNKNOWN
# 1        14292       UNKNOWN
# 2        14296       ALGERIA
# 3        14298       UNKNOWN
# 4        14207       UNKNOWN
# ...        ...           ...
# 6217      2886  NORHTEASTERN
# 6218      2887        ARRAYO
# 6219      2889        NORDAL
# 6220     14917   USS VIRGINA
# 6221     14635       UNKNOWN
#
#                                            Feature Type        Lat        Lng  \
# 0     Wreck - Submerged, dangerous to surface naviga...  42.143528 -80.114556
# 1     Wreck - Submerged, dangerous to surface naviga...  41.498284 -81.759593
# 2     Wreck - Submerged, dangerous to surface naviga...  41.520448 -81.716076
# 3     Wreck - Submerged, dangerous to surface naviga...  41.512713 -81.709879
# 4     Wreck - Submerged, dangerous to surface naviga...  42.993389 -82.426583
# ...                                                 ...        ...        ...
# ...

# %%
wrecks_df.to_csv("Resources/wrecks_transformed.csv", index = False)

# %%
dive_sites_df = wrecks_and_sites_df[["Dive Site ID", "Dive Site Name", "Distance from Wreck", 
                                     "Lat", "Lng", "Record #"]]

# %%
#dive_sites_df = dive_sites_df.rename(columns={"Record #" : "Wreck Record #"})

# %%
dive_sites_df
# Out:
#       Dive Site ID                 Dive Site Name  Distance from Wreck  \
# 0            23369                   Presque Isle                 1.97
# 1            23908                        Mecosta                17.20
# 2            23908                        Mecosta                16.96
# 3            23908                        Mecosta                16.34
# 4            22589                St. Clair River                 0.10
# ...            ...                            ...                  ...
# 6217         21172                     Empire Gem                 6.36
# 6218         17289                    Dixie Arrow                 6.18
# 6219         21175                         Tarpon                11.20
# 6220         23540                      Liberator                 8.09
# 6221         23578  Morehead City railroad bridge                 0.33
#
#             Lat        Lng  Record #
# 0     42.143528 -80.114556     14620
# 1     41.498284 -81.759593     14292
# ...

# %%
dive_sites_df.to_csv("Resources/dive_sites_transformed.csv", index = False)
